# %% [markdown]
# <a href="https://colab.research.google.com/github/sumamakhan761/Brain-tumor-classification/blob/main/Brain_Tumor_Classification_Using_DL_%26_GradCAM_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset/data")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sumamasarwar
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset
# Downloading brain-tumor-mri-dataset.zip to ./brain-tumor-mri-dataset
# 100%|██████████| 149M/149M [00:01<00:00, 130MB/s]

# %%
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.66.6)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.6.17)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.32.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.10)
# Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
import os
import random
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from IPython.display import Image
import imutils

# %%
os.mkdir("/content/Crop-Brain-MRI/")
os.mkdir("/content/Crop-Brain-MRI/glioma")
os.mkdir("/content/Crop-Brain-MRI/meningioma")
os.mkdir("/content/Crop-Brain-MRI/notumor")
os.mkdir("/content/Crop-Brain-MRI/pituitary")

# %%
os.mkdir("/content/Test-Data")
os.mkdir("/content/Test-Data/glioma")
os.mkdir("/content/Test-Data/meningioma")
os.mkdir("/content/Test-Data/notumor")
os.mkdir("/content/Test-Data/pituitary")

# %%
# Data Visulization

# %%
train_dir = "/content/brain-tumor-mri-dataset/Training/"
test_dir = "/content/brain-tumor-mri-dataset/Testing/"

# %%
classes = os.listdir("/content/brain-tumor-mri-dataset/Training/")

# %%
classes
# Out:
# ['meningioma', 'notumor', 'pituitary', 'glioma']

# %%
filepath_dict  ={}

for c in classes:
  filepath_dict[c] = list(map(lambda x : train_dir + c + '/' + x, os.listdir(train_dir + c)))

# %%
filepath_dict
# Out:
# {'meningioma': ['/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1154.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1037.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1065.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0137.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0693.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0850.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0598.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0785.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1314.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1267.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0727.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1282.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0545.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0019.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0961.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0498.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1243.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0584.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0677.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0455.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0491.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0423.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0362.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0290.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0317.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0459.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0202.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0818.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0377.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0168.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0500.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0690.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1105.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1240.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0424.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0024.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0684.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1236.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0547.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0157.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0296.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1041.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1071.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1134.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0329.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0987.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0029.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0472.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0588.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0580.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0221.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0666.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0903.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0723.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0576.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0056.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0922.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0597.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0730.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0262.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0453.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0783.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0921.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0263.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0815.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0417.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1225.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0100.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1296.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0893.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0972.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1230.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0082.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0639.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1207.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0341.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1162.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0538.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0356.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0192.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0631.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0182.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0124.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1176.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0034.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1080.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0083.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0335.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0420.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0069.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1042.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0486.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1223.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1077.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0353.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0699.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0154.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0212.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0736.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0934.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1280.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0924.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1098.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0959.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0266.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0283.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0910.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1179.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1333.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0227.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0711.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1174.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1233.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1002.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0139.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0912.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0746.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0207.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1189.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1262.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0872.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0824.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1188.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0675.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0330.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-meTr_0005.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0860.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0386.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0181.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0214.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0180.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0958.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0528.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0092.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0211.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1121.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1140.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0737.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0437.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0095.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0343.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0490.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0367.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0018.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0288.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0191.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1062.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0085.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0662.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0447.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0265.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0652.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0595.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0159.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0142.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0926.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0965.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0218.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0563.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0378.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1281.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0148.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0846.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0521.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0248.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0177.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0509.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0473.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0636.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0201.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0489.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0697.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1203.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1299.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1264.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0275.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0323.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0670.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1239.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1284.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0813.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0645.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0687.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0470.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0430.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0174.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1019.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1097.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0311.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0619.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0802.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0976.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1009.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0244.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0276.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1070.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0063.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0590.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0279.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1135.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0859.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1177.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0421.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0336.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0348.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1286.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1242.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0339.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1063.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1248.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0748.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0835.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0542.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0354.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1085.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0204.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0405.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0381.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0866.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0312.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0096.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0093.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0425.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0103.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1305.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0989.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0778.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0064.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1131.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0733.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1093.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0155.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0294.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0130.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0513.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1211.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0949.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0574.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1148.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0195.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0286.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1091.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0149.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0067.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0726.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0640.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0274.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0042.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0612.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0759.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0445.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1191.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0886.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0021.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1301.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0821.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0400.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0568.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0058.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0591.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0398.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0310.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0550.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-meTr_0001.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0062.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0495.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0106.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1228.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0537.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1021.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0780.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1141.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0887.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0918.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0271.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0097.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0185.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0760.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0990.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1144.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0247.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0387.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0057.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0190.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0791.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1196.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0725.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0565.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0979.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0280.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1238.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0023.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0010.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1335.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0573.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0836.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1256.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0880.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0702.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0075.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1129.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0522.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1285.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0966.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0322.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0224.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0066.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0865.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1152.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0140.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0249.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1003.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0443.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0761.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1069.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0258.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0217.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1029.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1294.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0927.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0546.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0539.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0800.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1128.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1324.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0661.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1302.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0524.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0186.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0494.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0308.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0586.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1310.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0646.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0892.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1076.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0104.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0439.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0888.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0637.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1067.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0534.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0981.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0327.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0696.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0210.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0707.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1033.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0257.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0480.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0930.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1307.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0188.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0151.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0856.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1114.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1331.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0564.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0076.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0605.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0673.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0277.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0594.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0938.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0928.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1247.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0553.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0309.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1153.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0187.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1297.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0749.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0479.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0116.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0575.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0383.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0040.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1304.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0873.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1306.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0474.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0070.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1235.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1227.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0715.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0351.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0318.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0601.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0669.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0109.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1271.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0841.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1311.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0523.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0022.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0569.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0753.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0809.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0102.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-meTr_0009.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0379.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1295.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-meTr_0002.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0906.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0710.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0991.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1011.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0986.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1018.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0832.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0233.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0241.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0220.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0716.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1204.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1159.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0272.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0406.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0295.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0487.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0481.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0375.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0923.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0703.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0968.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0899.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0101.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0729.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1132.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0135.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0469.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0964.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0446.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0795.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0817.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0484.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0801.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0492.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0465.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0593.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0978.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0665.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0559.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0579.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0891.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1273.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0642.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1010.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1001.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0916.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0503.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0852.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0765.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1059.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1146.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1035.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0788.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0435.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0344.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1234.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0434.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0571.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1329.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1194.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0438.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1048.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0413.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0391.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0342.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0829.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0624.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0913.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0905.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0404.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0871.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1004.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0797.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0600.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0984.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0236.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1275.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0065.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0409.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0402.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0038.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1170.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1316.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0982.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0240.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0555.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0436.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0952.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0985.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0845.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0518.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1265.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1096.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0457.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1007.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0126.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0251.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1241.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0505.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0933.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0268.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0037.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0441.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0531.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0680.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1330.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0810.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-meTr_0004.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1054.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1283.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0049.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0176.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1150.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0324.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0422.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0385.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0660.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0143.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1290.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0724.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-meTr_0006.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0955.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0460.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0267.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0416.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0772.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0842.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0840.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1045.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0384.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0622.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0046.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1136.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0828.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0080.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1086.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0427.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0618.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1078.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0743.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0281.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0890.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0763.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0199.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0026.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1231.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1195.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0779.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0485.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1084.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0138.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0811.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0347.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0581.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0161.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0349.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0585.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0020.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0297.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0941.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0882.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0881.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0861.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0052.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0209.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0171.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0995.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1293.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1082.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0946.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0306.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1292.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0650.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0045.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0692.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0519.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0867.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0977.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0851.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0183.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1210.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0647.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1101.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0110.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0502.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0031.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0681.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0368.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0578.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1127.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0956.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0146.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0900.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1315.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1287.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0516.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0036.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1049.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1061.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0072.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0544.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0158.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0475.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0173.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1219.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0270.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0862.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0592.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0313.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0777.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0980.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0883.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0633.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1198.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0431.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0254.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0833.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0794.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0152.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1184.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0620.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0557.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0583.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0957.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0668.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0869.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0250.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0655.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0719.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0695.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0433.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0252.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1068.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0397.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0305.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0284.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0051.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0015.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0393.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0549.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0896.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1213.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1298.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0520.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0904.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0682.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0526.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1079.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0653.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0971.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_1245.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0016.jpg',
#   '/content/brain-tumor-mri-dataset/Training/meningioma/Tr-me_0567.jpg',
# ...
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0848.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0234.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0761.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0298.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0072.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0598.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1051.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0482.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0835.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0868.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0942.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1130.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1244.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0256.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0418.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0312.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0577.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1289.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1072.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0031.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0759.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0950.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0933.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0379.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0485.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0581.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0295.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0406.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1042.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0346.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1017.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1270.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0864.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0998.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0812.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0731.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0676.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0325.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0416.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0121.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0589.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0747.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0465.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1236.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0923.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0539.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0877.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0510.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1047.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0337.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0592.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0112.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0807.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0954.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1181.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0371.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0216.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0654.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0613.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1218.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0556.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1295.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-glTr_0007.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0353.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0475.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0292.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0442.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0221.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1058.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1052.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0788.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1169.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0042.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1242.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0593.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0787.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1088.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1065.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0116.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1267.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0109.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0853.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0832.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0452.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1175.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1111.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0786.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0550.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0659.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0472.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0467.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0957.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1024.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1293.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0251.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0083.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0258.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0626.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0033.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1302.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0111.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0260.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0632.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1062.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0830.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0690.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0284.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0194.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0905.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0961.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0421.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1319.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0653.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0440.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1216.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0481.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0487.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1105.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1318.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0977.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0412.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0899.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0427.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0453.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0649.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0867.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0707.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0936.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0951.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0566.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0839.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0744.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0937.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1049.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0018.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0721.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0802.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0890.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0824.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0123.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1252.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0225.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1146.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0915.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0133.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1057.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0781.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0454.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0242.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0683.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1032.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1303.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0361.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0246.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0136.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1155.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0264.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0113.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0916.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0271.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0647.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0304.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0635.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0634.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0378.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-glTr_0002.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0527.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0766.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1277.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0856.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0667.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1135.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1103.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0511.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1030.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0430.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1136.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0492.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0355.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1150.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0415.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0294.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1269.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0993.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0804.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0992.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0914.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0043.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0958.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0170.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1080.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0815.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0674.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0373.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0777.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0155.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0755.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1117.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0728.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1093.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1011.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0236.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0076.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0267.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0345.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0646.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0206.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0840.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0502.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0041.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1061.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0178.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1234.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0214.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0562.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0305.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0431.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0257.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1194.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0034.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0087.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0464.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0793.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0270.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0826.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0604.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1313.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0197.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_1037.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0706.jpg',
#   '/content/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0726.jpg',
#   ...]}

# %%
from tensorflow.keras.preprocessing.image import load_img

plt.figure(figsize = (17, 17))

index = 0

for c in classes:
  random.shuffle(filepath_dict[c])
  path_list = filepath_dict[c][:5]

  for i in range(1, 5):
    index +=1
    plt.subplot(4, 4,index)
    plt.imshow(load_img(path_list[i]))
    plt.title(c)

# %%
No_images_per_class = []
Class_name = []
for i in os.listdir("/content/brain-tumor-mri-dataset/Training"):
  train_class = os.listdir(os.path.join("/content/brain-tumor-mri-dataset/Training", i))
  No_images_per_class.append(len(train_class))
  Class_name.append(i)
  print(f"Number of images in {i} : {len(train_class)}")
# Out:
# Number of images in meningioma : 1339
# Number of images in notumor : 1595
# Number of images in pituitary : 1457
# Number of images in glioma : 1321

# %%
plt.figure(figsize =(8, 8))
colors = sns.color_palette('pastel')
plt.pie(No_images_per_class, labels = Class_name, autopct = "%1.1f%%", colors = colors)
plt.show()

# %%
def crop_image(image, plot=False):

  img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  img_blur = cv2.GaussianBlur(img_gray, (5, 5), 0)
  img_thresh = cv2.threshold(img_blur, 45, 255, cv2.THRESH_BINARY)[1]
  img_thresh = cv2.erode(img_thresh, None, iterations = 2)
  img_thresh = cv2.dilate(img_thresh, None, iterations = 2)

  contours = cv2.findContours(img_thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

  contours = imutils.grab_contours(contours)

  c = max(contours, key = cv2.contourArea)

  extLeft = tuple(c[c[:, :, 0].argmin()])[0]
  extRight = tuple(c[c[:, :, 0].argmax()])[0]
  extTop = tuple(c[c[:, :, 1].argmin()])[0]
  extBottom = tuple(c[c[:, :, 1].argmax()])[0]

  new_img = image[extTop[1]: extBottom[1], extLeft[0]:extRight[0]]

  if plot:
    plt.figure(figsize = (15, 6))
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title("Original Image")
    plt.subplot(1, 2, 2)
    plt.imshow(new_img)
    plt.title("Cropped Image")
    plt.show()
  return new_img

# %%
example_img = cv2.imread("/content/brain-tumor-mri-dataset/Testing/glioma/Te-glTr_0000.jpg")
cropped_imgs = crop_image(example_img, plot=True)

# %%
example_img = cv2.imread("/content/brain-tumor-mri-dataset/Training/meningioma/Tr-meTr_0000.jpg")
cropped_imgs = crop_image(example_img, plot=True)

# %%
# Saving the cropped Images

# %%
glioma = train_dir + 'glioma'
meningioma = train_dir + 'meningioma'
pituitary = train_dir + 'pituitary'
notumor = train_dir + 'notumor'
j = 0
for i in tqdm(os.listdir(glioma)):
  path = os.path.join(glioma , i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)
  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Crop-Brain-MRI/glioma/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1
# Out:
# 100%|██████████| 1321/1321 [00:04<00:00, 296.44it/s]

# %%
j = 0
for i in tqdm(os.listdir(meningioma)):
  path = os.path.join(meningioma , i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)
  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Crop-Brain-MRI/meningioma/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1

j = 0
for i in tqdm(os.listdir(pituitary)):
  path = os.path.join(pituitary , i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)
  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Crop-Brain-MRI/pituitary/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1

j = 0
for i in tqdm(os.listdir(notumor)):
  path = os.path.join(notumor , i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)
  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Crop-Brain-MRI/notumor/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1
# Out:
# 100%|██████████| 1339/1339 [00:03<00:00, 360.80it/s]
# 100%|██████████| 1457/1457 [00:07<00:00, 191.84it/s]
# 100%|██████████| 1595/1595 [00:03<00:00, 480.85it/s]

# %%
len(os.listdir(glioma))
# Out:
# 1321

# %%
test_glioma = test_dir + 'glioma'
test_meningioma = test_dir + 'meningioma'
test_pituitary = test_dir + 'pituitary'
test_no_tumor = test_dir + 'notumor'
j = 0
for i in tqdm(os.listdir(test_glioma)):
  path = os.path.join(test_glioma , i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)
  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Test-Data/glioma/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1
# Out:
# 100%|██████████| 300/300 [00:00<00:00, 355.98it/s]

# %%
j = 0
for i in tqdm(os.listdir(test_meningioma)):
  path = os.path.join(test_meningioma , i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)
  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Test-Data/meningioma/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1

j = 0
for i in tqdm(os.listdir(test_pituitary)):
  path = os.path.join(test_pituitary , i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)
  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Test-Data/pituitary/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1

j = 0
for i in tqdm(os.listdir(test_no_tumor)):
  path = os.path.join(test_no_tumor , i)
  img = cv2.imread(path)
  img = crop_image(img, plot=False)
  if img is not None:
    img = cv2.resize(img, (240, 240))
    save_path = '/content/Test-Data/notumor/' + str(j) + '.jpg'
    cv2.imwrite(save_path, img)
    j = j + 1
# Out:
# 100%|██████████| 306/306 [00:00<00:00, 363.92it/s]
# 100%|██████████| 300/300 [00:00<00:00, 334.64it/s]
# 100%|██████████| 405/405 [00:00<00:00, 583.50it/s]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array

# %%
datagen = ImageDataGenerator(rotation_range = 10,
                             height_shift_range = 0.2,
                             horizontal_flip = True,
                             validation_split = 0.2)

train_data = datagen.flow_from_directory('/content/Crop-Brain-MRI/',
                            target_size = (240, 240),
                            batch_size = 32,
                            class_mode = 'categorical', subset = 'training')

valid_data = datagen.flow_from_directory('/content/Crop-Brain-MRI/',
                            target_size = (240, 240),
                            batch_size = 32,
                            class_mode = 'categorical', subset = 'validation')

test_datagen = ImageDataGenerator()

test_data = datagen.flow_from_directory('/content/Test-Data/',
                            target_size = (240, 240),
                            class_mode = 'categorical', shuffle = False)
# Out:
# Found 4571 images belonging to 4 classes.
# Found 1141 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %%
test_data.class_indices
# Out:
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %%
sample_x, sample_y = next(train_data)

plt.figure(figsize = (12, 9))

for i in range(6):
  plt.subplot(2, 3, i+1)
  sample = array_to_img(sample_x[i])
  plt.axis('off')
  plt.grid(False)
  plt.imshow(sample)

plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Conv2D, Dropout, GlobalMaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
effenet  = EfficientNetB1(weights = 'imagenet', include_top = False, input_shape = (240, 240, 3))

model = effenet.output
model = GlobalMaxPooling2D()(model)
model = Dropout(0.5)(model)
model = Dense(4, activation="softmax")(model)
model = Model(inputs=effenet.input, outputs = model)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27018416/27018416 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 240, 240, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling (Rescaling)     │ (None, 240, 240, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization             │ (None, 240, 240, 3)    │              7 │ rescaling[0][0]        │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling_1 (Rescaling)   │ (None, 240, 240, 3)    │              0 │ normalization[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv_pad             │ (None, 241, 241, 3)    │              0 │ rescaling_1[0][0]      │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv (Conv2D)        │ (None, 120, 120, 32)   │            864 │ stem_conv_pad[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_bn                   │ (None, 120, 120, 32)   │            128 │ stem_conv[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_activation           │ (None, 120, 120, 32)   │              0 │ stem_bn[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_dwconv            │ (None, 120, 120, 32)   │            288 │ stem_activation[0][0]  │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_bn                │ (None, 120, 120, 32)   │            128 │ block1a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_activation        │ (None, 120, 120, 32)   │              0 │ block1a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_squeeze        │ (None, 32)             │              0 │ block1a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reshape        │ (None, 1, 1, 32)       │              0 │ block1a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reduce         │ (None, 1, 1, 8)        │            264 │ block1a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_expand         │ (None, 1, 1, 32)       │            288 │ block1a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_excite         │ (None, 120, 120, 32)   │              0 │ block1a_activation[0]… │
# │ (Multiply)                │                        │                │ block1a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_conv      │ (None, 120, 120, 16)   │            512 │ block1a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_bn        │ (None, 120, 120, 16)   │             64 │ block1a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_dwconv            │ (None, 120, 120, 16)   │            144 │ block1a_project_bn[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_bn                │ (None, 120, 120, 16)   │             64 │ block1b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_activation        │ (None, 120, 120, 16)   │              0 │ block1b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_squeeze        │ (None, 16)             │              0 │ block1b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_reshape        │ (None, 1, 1, 16)       │              0 │ block1b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_reduce         │ (None, 1, 1, 4)        │             68 │ block1b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_expand         │ (None, 1, 1, 16)       │             80 │ block1b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_excite         │ (None, 120, 120, 16)   │              0 │ block1b_activation[0]… │
# │ (Multiply)                │                        │                │ block1b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_conv      │ (None, 120, 120, 16)   │            256 │ block1b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_bn        │ (None, 120, 120, 16)   │             64 │ block1b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_drop (Dropout)    │ (None, 120, 120, 16)   │              0 │ block1b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_add (Add)         │ (None, 120, 120, 16)   │              0 │ block1b_drop[0][0],    │
# │                           │                        │                │ block1a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_conv       │ (None, 120, 120, 96)   │          1,536 │ block1b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_bn         │ (None, 120, 120, 96)   │            384 │ block2a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_activation │ (None, 120, 120, 96)   │              0 │ block2a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv_pad        │ (None, 121, 121, 96)   │              0 │ block2a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv            │ (None, 60, 60, 96)     │            864 │ block2a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_bn                │ (None, 60, 60, 96)     │            384 │ block2a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_activation        │ (None, 60, 60, 96)     │              0 │ block2a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_squeeze        │ (None, 96)             │              0 │ block2a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reshape        │ (None, 1, 1, 96)       │              0 │ block2a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reduce         │ (None, 1, 1, 4)        │            388 │ block2a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_expand         │ (None, 1, 1, 96)       │            480 │ block2a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_excite         │ (None, 60, 60, 96)     │              0 │ block2a_activation[0]… │
# │ (Multiply)                │                        │                │ block2a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_conv      │ (None, 60, 60, 24)     │          2,304 │ block2a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_bn        │ (None, 60, 60, 24)     │             96 │ block2a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_conv       │ (None, 60, 60, 144)    │          3,456 │ block2a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_bn         │ (None, 60, 60, 144)    │            576 │ block2b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_activation │ (None, 60, 60, 144)    │              0 │ block2b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_dwconv            │ (None, 60, 60, 144)    │          1,296 │ block2b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_bn                │ (None, 60, 60, 144)    │            576 │ block2b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_activation        │ (None, 60, 60, 144)    │              0 │ block2b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_squeeze        │ (None, 144)            │              0 │ block2b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reshape        │ (None, 1, 1, 144)      │              0 │ block2b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reduce         │ (None, 1, 1, 6)        │            870 │ block2b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_expand         │ (None, 1, 1, 144)      │          1,008 │ block2b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_excite         │ (None, 60, 60, 144)    │              0 │ block2b_activation[0]… │
# │ (Multiply)                │                        │                │ block2b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_conv      │ (None, 60, 60, 24)     │          3,456 │ block2b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_bn        │ (None, 60, 60, 24)     │             96 │ block2b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_drop (Dropout)    │ (None, 60, 60, 24)     │              0 │ block2b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_add (Add)         │ (None, 60, 60, 24)     │              0 │ block2b_drop[0][0],    │
# │                           │                        │                │ block2a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_conv       │ (None, 60, 60, 144)    │          3,456 │ block2b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_bn         │ (None, 60, 60, 144)    │            576 │ block2c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_activation │ (None, 60, 60, 144)    │              0 │ block2c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_dwconv            │ (None, 60, 60, 144)    │          1,296 │ block2c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_bn                │ (None, 60, 60, 144)    │            576 │ block2c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_activation        │ (None, 60, 60, 144)    │              0 │ block2c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_squeeze        │ (None, 144)            │              0 │ block2c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reshape        │ (None, 1, 1, 144)      │              0 │ block2c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reduce         │ (None, 1, 1, 6)        │            870 │ block2c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_expand         │ (None, 1, 1, 144)      │          1,008 │ block2c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_excite         │ (None, 60, 60, 144)    │              0 │ block2c_activation[0]… │
# │ (Multiply)                │                        │                │ block2c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_conv      │ (None, 60, 60, 24)     │          3,456 │ block2c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_bn        │ (None, 60, 60, 24)     │             96 │ block2c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_drop (Dropout)    │ (None, 60, 60, 24)     │              0 │ block2c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_add (Add)         │ (None, 60, 60, 24)     │              0 │ block2c_drop[0][0],    │
# │                           │                        │                │ block2b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_conv       │ (None, 60, 60, 144)    │          3,456 │ block2c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_bn         │ (None, 60, 60, 144)    │            576 │ block3a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_activation │ (None, 60, 60, 144)    │              0 │ block3a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv_pad        │ (None, 63, 63, 144)    │              0 │ block3a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv            │ (None, 30, 30, 144)    │          3,600 │ block3a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_bn                │ (None, 30, 30, 144)    │            576 │ block3a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_activation        │ (None, 30, 30, 144)    │              0 │ block3a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_squeeze        │ (None, 144)            │              0 │ block3a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reshape        │ (None, 1, 1, 144)      │              0 │ block3a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reduce         │ (None, 1, 1, 6)        │            870 │ block3a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_expand         │ (None, 1, 1, 144)      │          1,008 │ block3a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_excite         │ (None, 30, 30, 144)    │              0 │ block3a_activation[0]… │
# │ (Multiply)                │                        │                │ block3a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_conv      │ (None, 30, 30, 40)     │          5,760 │ block3a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_bn        │ (None, 30, 30, 40)     │            160 │ block3a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_conv       │ (None, 30, 30, 240)    │          9,600 │ block3a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_bn         │ (None, 30, 30, 240)    │            960 │ block3b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_activation │ (None, 30, 30, 240)    │              0 │ block3b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_dwconv            │ (None, 30, 30, 240)    │          6,000 │ block3b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_bn                │ (None, 30, 30, 240)    │            960 │ block3b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_activation        │ (None, 30, 30, 240)    │              0 │ block3b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_squeeze        │ (None, 240)            │              0 │ block3b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reshape        │ (None, 1, 1, 240)      │              0 │ block3b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reduce         │ (None, 1, 1, 10)       │          2,410 │ block3b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_expand         │ (None, 1, 1, 240)      │          2,640 │ block3b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_excite         │ (None, 30, 30, 240)    │              0 │ block3b_activation[0]… │
# │ (Multiply)                │                        │                │ block3b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_conv      │ (None, 30, 30, 40)     │          9,600 │ block3b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_bn        │ (None, 30, 30, 40)     │            160 │ block3b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_drop (Dropout)    │ (None, 30, 30, 40)     │              0 │ block3b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_add (Add)         │ (None, 30, 30, 40)     │              0 │ block3b_drop[0][0],    │
# │                           │                        │                │ block3a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_conv       │ (None, 30, 30, 240)    │          9,600 │ block3b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_bn         │ (None, 30, 30, 240)    │            960 │ block3c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_activation │ (None, 30, 30, 240)    │              0 │ block3c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_dwconv            │ (None, 30, 30, 240)    │          6,000 │ block3c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_bn                │ (None, 30, 30, 240)    │            960 │ block3c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_activation        │ (None, 30, 30, 240)    │              0 │ block3c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_squeeze        │ (None, 240)            │              0 │ block3c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_reshape        │ (None, 1, 1, 240)      │              0 │ block3c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_reduce         │ (None, 1, 1, 10)       │          2,410 │ block3c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_expand         │ (None, 1, 1, 240)      │          2,640 │ block3c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_excite         │ (None, 30, 30, 240)    │              0 │ block3c_activation[0]… │
# │ (Multiply)                │                        │                │ block3c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_conv      │ (None, 30, 30, 40)     │          9,600 │ block3c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_bn        │ (None, 30, 30, 40)     │            160 │ block3c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_drop (Dropout)    │ (None, 30, 30, 40)     │              0 │ block3c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_add (Add)         │ (None, 30, 30, 40)     │              0 │ block3c_drop[0][0],    │
# │                           │                        │                │ block3b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_conv       │ (None, 30, 30, 240)    │          9,600 │ block3c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_bn         │ (None, 30, 30, 240)    │            960 │ block4a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_activation │ (None, 30, 30, 240)    │              0 │ block4a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv_pad        │ (None, 31, 31, 240)    │              0 │ block4a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv            │ (None, 15, 15, 240)    │          2,160 │ block4a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_bn                │ (None, 15, 15, 240)    │            960 │ block4a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_activation        │ (None, 15, 15, 240)    │              0 │ block4a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_squeeze        │ (None, 240)            │              0 │ block4a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reshape        │ (None, 1, 1, 240)      │              0 │ block4a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reduce         │ (None, 1, 1, 10)       │          2,410 │ block4a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_expand         │ (None, 1, 1, 240)      │          2,640 │ block4a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_excite         │ (None, 15, 15, 240)    │              0 │ block4a_activation[0]… │
# │ (Multiply)                │                        │                │ block4a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_conv      │ (None, 15, 15, 80)     │         19,200 │ block4a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_bn        │ (None, 15, 15, 80)     │            320 │ block4a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_conv       │ (None, 15, 15, 480)    │         38,400 │ block4a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_bn         │ (None, 15, 15, 480)    │          1,920 │ block4b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_activation │ (None, 15, 15, 480)    │              0 │ block4b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_dwconv            │ (None, 15, 15, 480)    │          4,320 │ block4b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_bn                │ (None, 15, 15, 480)    │          1,920 │ block4b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_activation        │ (None, 15, 15, 480)    │              0 │ block4b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_squeeze        │ (None, 480)            │              0 │ block4b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reshape        │ (None, 1, 1, 480)      │              0 │ block4b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reduce         │ (None, 1, 1, 20)       │          9,620 │ block4b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_expand         │ (None, 1, 1, 480)      │         10,080 │ block4b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_excite         │ (None, 15, 15, 480)    │              0 │ block4b_activation[0]… │
# │ (Multiply)                │                        │                │ block4b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_conv      │ (None, 15, 15, 80)     │         38,400 │ block4b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_bn        │ (None, 15, 15, 80)     │            320 │ block4b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_drop (Dropout)    │ (None, 15, 15, 80)     │              0 │ block4b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_add (Add)         │ (None, 15, 15, 80)     │              0 │ block4b_drop[0][0],    │
# │                           │                        │                │ block4a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_conv       │ (None, 15, 15, 480)    │         38,400 │ block4b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_bn         │ (None, 15, 15, 480)    │          1,920 │ block4c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_activation │ (None, 15, 15, 480)    │              0 │ block4c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_dwconv            │ (None, 15, 15, 480)    │          4,320 │ block4c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_bn                │ (None, 15, 15, 480)    │          1,920 │ block4c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_activation        │ (None, 15, 15, 480)    │              0 │ block4c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_squeeze        │ (None, 480)            │              0 │ block4c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reshape        │ (None, 1, 1, 480)      │              0 │ block4c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reduce         │ (None, 1, 1, 20)       │          9,620 │ block4c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_expand         │ (None, 1, 1, 480)      │         10,080 │ block4c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_excite         │ (None, 15, 15, 480)    │              0 │ block4c_activation[0]… │
# │ (Multiply)                │                        │                │ block4c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_conv      │ (None, 15, 15, 80)     │         38,400 │ block4c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_bn        │ (None, 15, 15, 80)     │            320 │ block4c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_drop (Dropout)    │ (None, 15, 15, 80)     │              0 │ block4c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_add (Add)         │ (None, 15, 15, 80)     │              0 │ block4c_drop[0][0],    │
# │                           │                        │                │ block4b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_conv       │ (None, 15, 15, 480)    │         38,400 │ block4c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_bn         │ (None, 15, 15, 480)    │          1,920 │ block4d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_activation │ (None, 15, 15, 480)    │              0 │ block4d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_dwconv            │ (None, 15, 15, 480)    │          4,320 │ block4d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_bn                │ (None, 15, 15, 480)    │          1,920 │ block4d_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_se_reduce         │ (None, 1, 1, 48)       │         55,344 │ block6d_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_se_expand         │ (None, 1, 1, 1152)     │         56,448 │ block6d_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_se_excite         │ (None, 8, 8, 1152)     │              0 │ block6d_activation[0]… │
# │ (Multiply)                │                        │                │ block6d_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_project_conv      │ (None, 8, 8, 192)      │        221,184 │ block6d_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_project_bn        │ (None, 8, 8, 192)      │            768 │ block6d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_drop (Dropout)    │ (None, 8, 8, 192)      │              0 │ block6d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6d_add (Add)         │ (None, 8, 8, 192)      │              0 │ block6d_drop[0][0],    │
# │                           │                        │                │ block6c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_expand_conv       │ (None, 8, 8, 1152)     │        221,184 │ block6d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_expand_bn         │ (None, 8, 8, 1152)     │          4,608 │ block6e_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_expand_activation │ (None, 8, 8, 1152)     │              0 │ block6e_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_dwconv            │ (None, 8, 8, 1152)     │         28,800 │ block6e_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_bn                │ (None, 8, 8, 1152)     │          4,608 │ block6e_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_activation        │ (None, 8, 8, 1152)     │              0 │ block6e_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_se_squeeze        │ (None, 1152)           │              0 │ block6e_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_se_reshape        │ (None, 1, 1, 1152)     │              0 │ block6e_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_se_reduce         │ (None, 1, 1, 48)       │         55,344 │ block6e_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_se_expand         │ (None, 1, 1, 1152)     │         56,448 │ block6e_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_se_excite         │ (None, 8, 8, 1152)     │              0 │ block6e_activation[0]… │
# │ (Multiply)                │                        │                │ block6e_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_project_conv      │ (None, 8, 8, 192)      │        221,184 │ block6e_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_project_bn        │ (None, 8, 8, 192)      │            768 │ block6e_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_drop (Dropout)    │ (None, 8, 8, 192)      │              0 │ block6e_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6e_add (Add)         │ (None, 8, 8, 192)      │              0 │ block6e_drop[0][0],    │
# │                           │                        │                │ block6d_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_conv       │ (None, 8, 8, 1152)     │        221,184 │ block6e_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_bn         │ (None, 8, 8, 1152)     │          4,608 │ block7a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_expand_activation │ (None, 8, 8, 1152)     │              0 │ block7a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_dwconv            │ (None, 8, 8, 1152)     │         10,368 │ block7a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_bn                │ (None, 8, 8, 1152)     │          4,608 │ block7a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_activation        │ (None, 8, 8, 1152)     │              0 │ block7a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_squeeze        │ (None, 1152)           │              0 │ block7a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_reshape        │ (None, 1, 1, 1152)     │              0 │ block7a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_reduce         │ (None, 1, 1, 48)       │         55,344 │ block7a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_expand         │ (None, 1, 1, 1152)     │         56,448 │ block7a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_se_excite         │ (None, 8, 8, 1152)     │              0 │ block7a_activation[0]… │
# │ (Multiply)                │                        │                │ block7a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_project_conv      │ (None, 8, 8, 320)      │        368,640 │ block7a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7a_project_bn        │ (None, 8, 8, 320)      │          1,280 │ block7a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_conv       │ (None, 8, 8, 1920)     │        614,400 │ block7a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_bn         │ (None, 8, 8, 1920)     │          7,680 │ block7b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_activation │ (None, 8, 8, 1920)     │              0 │ block7b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_dwconv            │ (None, 8, 8, 1920)     │         17,280 │ block7b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_bn                │ (None, 8, 8, 1920)     │          7,680 │ block7b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_activation        │ (None, 8, 8, 1920)     │              0 │ block7b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_squeeze        │ (None, 1920)           │              0 │ block7b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_reshape        │ (None, 1, 1, 1920)     │              0 │ block7b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_reduce         │ (None, 1, 1, 80)       │        153,680 │ block7b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_expand         │ (None, 1, 1, 1920)     │        155,520 │ block7b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_excite         │ (None, 8, 8, 1920)     │              0 │ block7b_activation[0]… │
# │ (Multiply)                │                        │                │ block7b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_project_conv      │ (None, 8, 8, 320)      │        614,400 │ block7b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_project_bn        │ (None, 8, 8, 320)      │          1,280 │ block7b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_drop (Dropout)    │ (None, 8, 8, 320)      │              0 │ block7b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_add (Add)         │ (None, 8, 8, 320)      │              0 │ block7b_drop[0][0],    │
# │                           │                        │                │ block7a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_conv (Conv2D)         │ (None, 8, 8, 1280)     │        409,600 │ block7b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_bn                    │ (None, 8, 8, 1280)     │          5,120 │ top_conv[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_activation            │ (None, 8, 8, 1280)     │              0 │ top_bn[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d      │ (None, 1280)           │              0 │ top_activation[0][0]   │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 1280)           │              0 │ global_max_pooling2d[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 4)              │          5,124 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 6,580,363 (25.10 MB)
#  Trainable params: 6,518,308 (24.87 MB)
#  Non-trainable params: 62,055 (242.41 KB)

# %%
model.compile(optimizer=Adam(learning_rate = 0.0001),
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])
checkpoint = ModelCheckpoint('model.keras', monitor = 'val_accuracy',
                save_best_only = True,
                mode = 'auto',
                verbose = 1)
earlystop = EarlyStopping(monitor = 'val_accuracy',
              patience = 5,
              mode = 'auto', verbose = 1)

reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy',
                  factor = 0.3,
                  patience = 2,
                  min_delta = 0.001,
                  mode = 'auto', verbose = 1)

# %%
# %%time
history = model.fit(train_data, epochs = 30, validation_data = valid_data,
                    verbose = 1, callbacks = [checkpoint, earlystop, reduce_lr])
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 963ms/step - accuracy: 0.4848 - loss: 4.2771
# Epoch 1: val_accuracy improved from -inf to 0.70727, saving model to model.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 286s 1s/step - accuracy: 0.4859 - loss: 4.2649 - val_accuracy: 0.7073 - val_loss: 1.1600 - learning_rate: 1.0000e-04
# Epoch 2/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.8369 - loss: 0.9242
# Epoch 2: val_accuracy improved from 0.70727 to 0.85013, saving model to model.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 85s 579ms/step - accuracy: 0.8371 - loss: 0.9232 - val_accuracy: 0.8501 - val_loss: 0.7026 - learning_rate: 1.0000e-04
# Epoch 3/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.8866 - loss: 0.5395
# Epoch 3: val_accuracy improved from 0.85013 to 0.88606, saving model to model.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 142s 571ms/step - accuracy: 0.8867 - loss: 0.5390 - val_accuracy: 0.8861 - val_loss: 0.6496 - learning_rate: 1.0000e-04
# Epoch 4/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9182 - loss: 0.3078
# Epoch 4: val_accuracy improved from 0.88606 to 0.89571, saving model to model.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 84s 572ms/step - accuracy: 0.9182 - loss: 0.3077 - val_accuracy: 0.8957 - val_loss: 0.4563 - learning_rate: 1.0000e-04
# Epoch 5/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9342 - loss: 0.2475
# Epoch 5: val_accuracy improved from 0.89571 to 0.93777, saving model to model.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 143s 574ms/step - accuracy: 0.9343 - loss: 0.2474 - val_accuracy: 0.9378 - val_loss: 0.2360 - learning_rate: 1.0000e-04
# Epoch 6/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.9520 - loss: 0.1526
# Epoch 6: val_accuracy improved from 0.93777 to 0.96670, saving model to model.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 140s 570ms/step - accuracy: 0.9520 - loss: 0.1526 - val_accuracy: 0.9667 - val_loss: 0.1183 - learning_rate: 1.0000e-04
# Epoch 7/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.9615 - loss: 0.1080
# Epoch 7: val_accuracy improved from 0.96670 to 0.96845, saving model to model.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 84s 570ms/step - accuracy: 0.9615 - loss: 0.1079 - val_accuracy: 0.9684 - val_loss: 0.1062 - learning_rate: 1.0000e-04
# Epoch 8/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9718 - loss: 0.0985
# Epoch 8: val_accuracy improved from 0.96845 to 0.97195, saving model to model.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 84s 565ms/step - accuracy: 0.9718 - loss: 0.0984 - val_accuracy: 0.9720 - val_loss: 0.0788 - learning_rate: 1.0000e-04
# Epoch 9/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9763 - loss: 0.0771
# Epoch 9: val_accuracy did not improve from 0.97195
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 141s 564ms/step - accuracy: 0.9763 - loss: 0.0771 - val_accuracy: 0.9649 - val_loss: 0.1107 - learning_rate: 1.0000e-04
# Epoch 10/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9739 - loss: 0.0657
# Epoch 10: val_accuracy improved from 0.97195 to 0.97721, saving model to model.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 144s 571ms/step - accuracy: 0.9739 - loss: 0.0657 - val_accuracy: 0.9772 - val_loss: 0.0838 - learning_rate: 1.0000e-04
# Epoch 11/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9838 - loss: 0.0454
# Epoch 11: val_accuracy improved from 0.97721 to 0.98072, saving model to model.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 142s 575ms/step - accuracy: 0.9838 - loss: 0.0454 - val_accuracy: 0.9807 - val_loss: 0.0751 - learning_rate: 1.0000e-04
# Epoch 12/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9790 - loss: 0.0548
# Epoch 12: val_accuracy did not improve from 0.98072
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 83s 565ms/step - accuracy: 0.9790 - loss: 0.0547 - val_accuracy: 0.9781 - val_loss: 0.1005 - learning_rate: 1.0000e-04
# Epoch 13/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.9865 - loss: 0.0549
# Epoch 13: val_accuracy did not improve from 0.98072
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 84s 561ms/step - accuracy: 0.9865 - loss: 0.0549 - val_accuracy: 0.9790 - val_loss: 0.0955 - learning_rate: 1.0000e-04
# Epoch 14/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.9886 - loss: 0.0358
# Epoch 14: val_accuracy did not improve from 0.98072
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 83s 564ms/step - accuracy: 0.9886 - loss: 0.0357 - val_accuracy: 0.9798 - val_loss: 0.0873 - learning_rate: 3.0000e-05
# Epoch 15/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9879 - loss: 0.0326
# Epoch 15: val_accuracy improved from 0.98072 to 0.98422, saving model to model.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 149s 615ms/step - accuracy: 0.9879 - loss: 0.0326 - val_accuracy: 0.9842 - val_loss: 0.0935 - learning_rate: 3.0000e-05
# Epoch 16/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9865 - loss: 0.0372
# Epoch 16: val_accuracy did not improve from 0.98422
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 141s 601ms/step - accuracy: 0.9866 - loss: 0.0371 - val_accuracy: 0.9790 - val_loss: 0.0980 - learning_rate: 3.0000e-05
# Epoch 17/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9927 - loss: 0.0236
# Epoch 17: val_accuracy did not improve from 0.98422
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 84s 558ms/step - accuracy: 0.9927 - loss: 0.0236 - val_accuracy: 0.9790 - val_loss: 0.0859 - learning_rate: 3.0000e-05
# Epoch 18/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.9927 - loss: 0.0232
# Epoch 18: val_accuracy did not improve from 0.98422
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 86s 584ms/step - accuracy: 0.9927 - loss: 0.0232 - val_accuracy: 0.9842 - val_loss: 0.0887 - learning_rate: 9.0000e-06
# Epoch 19/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9935 - loss: 0.0191
# Epoch 19: val_accuracy improved from 0.98422 to 0.98510, saving model to model.keras
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 140s 571ms/step - accuracy: 0.9935 - loss: 0.0191 - val_accuracy: 0.9851 - val_loss: 0.0867 - learning_rate: 9.0000e-06
# Epoch 20/30

# %%
fig, ax = plt.subplots(1 , 2)
fig.set_size_inches(20, 8)

train_acc = history.history['accuracy']
train_loss = history.history['loss']

val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']


epochs = range(1, len(train_acc) + 1)

ax[0].plot(epochs, train_acc, 'g-o', label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, 'y-o', label = 'Validation Accuracy')
ax[0].set_title('Model Training & Validation Accuracy')
ax[0].legend(loc = 'lower right')
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'g-o', label = 'Training loss')
ax[1].plot(epochs, val_loss, 'y-o', label = 'Validation loss')
ax[1].set_title('Model Training & Validation loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")
plt.show()

# %%
model.evaluate(train_data)

# %%
model.evaluate(test_data)

# %%
y_test = test_data.classes
y_test_hat = np.argmax(model.predict(test_data), axis = 1)

# %%
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix, classification_report

# %%
cm = confusion_matrix(y_test, y_test_hat)
cm

# %%
test_data.class_indices

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ['glioma', 'meningioma', 'notumor', 'pituitary'])
cm_display.plot()
plt.show()

# %%
print(classification_report(y_test, y_test_hat))

# %%
# Prediction on Test Img

# %%
import PIL

CLASS_DICT = {0: 'glioma', 1: 'meningioma', 2: 'notumor', 3: 'pituitary'}

images = []
prediction = []
original = []

for i in os.listdir('/content/Test-Data'):
  for item in os.listdir(os.path.join('/content/Test-Data', i)):
    img = PIL.Image.open(os.path.join('/content/Test-Data', i, item))
    images.append(img)
    img = np.expand_dims(img, axis = 0)
    predict = model.predict(img)
    predict = np.argmax(predict)
    prediction.append(CLASS_DICT[predict])
    original.append(i)

# %%
score = accuracy_score(original, prediction)
score

# %%
fig = plt.figure(figsize = (20, 20))

for i in range(10):
  j = random.randint(0, len(images))
  fig.add_subplot(5, 2, i+1)
  plt.xlabel("Prediction : " + prediction[j] + "   Original:    " + original[j])
  plt.imshow(images[j])
fig.tight_layout()
plt.show()

# %%
import tensorflow as tf
last_conv_layer = next(x for x in model.layers[::-1] if isinstance(x, tf.keras.layers.Conv2D))
last_conv_layer.name

# %%
import cv2
import numpy as np
from PIL import Image
import tensorflow as tf
import tensorflow.keras as K
import matplotlib.pyplot as plt
from skimage.transform import resize
from tensorflow.keras.models import Model


def VizGradCAM(model, image, interpolant=0.5, plot_results=True):
    """VizGradCAM - Displays GradCAM based on Keras / TensorFlow models
    using the gradients from the last convolutional layer. This function
    should work with all Keras Application listed here:
    https://keras.io/api/applications/

    Parameters:
    model (keras.model): Compiled Model with Weights Loaded
    image: Image to Perform Inference On
    plot_results (boolean): True - Function Plots using PLT
                            False - Returns Heatmap Array

    Returns:
    Heatmap Array?
    """
    # Sanity Check
    assert (
        interpolant > 0 and interpolant < 1
    ), "Heatmap Interpolation Must Be Between 0 - 1"

    last_conv_layer = next(
        x for x in model.layers[::-1] if isinstance(x, K.layers.Conv2D)
    )
    target_layer = model.get_layer(last_conv_layer.name)

    original_img = image
    img = np.expand_dims(original_img, axis=0)
    prediction = model.predict(img)

    # Obtain Prediction Index
    prediction_idx = np.argmax(prediction)

    # Compute Gradient of Top Predicted Class
    with tf.GradientTape() as tape:
        gradient_model = Model([model.inputs], [target_layer.output, model.output])
        conv2d_out, prediction = gradient_model(img)
        # Obtain the Prediction Loss
        loss = prediction[:, prediction_idx]

    # Gradient() computes the gradient using operations recorded
    # in context of this tape
    gradients = tape.gradient(loss, conv2d_out)

    # Obtain the Output from Shape [1 x H x W x CHANNEL] -> [H x W x CHANNEL]
    output = conv2d_out[0]

    # Obtain Depthwise Mean
    weights = tf.reduce_mean(gradients[0], axis=(0, 1))

    # Create a 7x7 Map for Aggregation
    activation_map = np.zeros(output.shape[0:2], dtype=np.float32)

    # Multiply Weights with Every Layer
    for idx, weight in enumerate(weights):
        activation_map += weight * output[:, :, idx]

    # Resize to Size of Image
    activation_map = cv2.resize(
        activation_map.numpy(), (original_img.shape[1], original_img.shape[0])
    )

    # Ensure No Negative Numbers
    activation_map = np.maximum(activation_map, 0)

    # Convert Class Activation Map to 0 - 255
    activation_map = (activation_map - activation_map.min()) / (
        activation_map.max() - activation_map.min()
    )
    activation_map = np.uint8(255 * activation_map)

    # Convert to Heatmap
    heatmap = cv2.applyColorMap(activation_map, cv2.COLORMAP_JET)

    # Superimpose Heatmap on Image Data
    original_img = np.uint8(
        (original_img - original_img.min())
        / (original_img.max() - original_img.min())
        * 255
    )

    cvt_heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)

    # Enlarge Plot
    plt.rcParams["figure.dpi"] = 100

    if plot_results == True:
        plt.imshow(
            np.uint8(original_img * interpolant + cvt_heatmap * (1 - interpolant))
        )
    else:
        return cvt_heatmap

# %%
test_img = cv2.imread("/content/Test-Data/glioma/2.jpg")
VizGradCAM(model, img_to_array(test_img), plot_results=True)
